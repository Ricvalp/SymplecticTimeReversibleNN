# %% [markdown]
# ## Henon Heiles: Reversible Polynomial Henon Maps

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import math as mt
from tensorflow import keras
from tensorflow.keras import layers
import time
import wandb
import os
import sys
import random as rd

sys.path.append("..")

from AllMethods import ReversibleSymplecticNN as rs
from AllMethods import PerturbedPendulum_Methods as pp

gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %% [markdown]
# ### Import Training Dataset

# %%
x, y = pp.read_dataset('x_train.txt', 'y_train.txt')

# %%
pp.plot_dataset(x,y)

# %% [markdown]
# ### Training Dataset

# %%
train_dataset, val_dataset = pp.train_dataset(x, y, 10000, 50000, 10000) #val_len, train_batch, val_batch

# %% [markdown]
# ### Model

# %%
class MyModel10(tf.keras.Model):

    def __init__(self):
        super(MyModel, self).__init__()
        self.dense1 = tf.keras.layers.Dense(2, activation=tf.nn.tanh)
        
        self.dense2 = tf.keras.layers.Dense(10, activation=tf.nn.tanh)
        self.dense3 = tf.keras.layers.Dense(10, activation=tf.nn.tanh)
        
        self.dense4 = tf.keras.layers.Dense(2, activation=tf.nn.tanh)

    def call(self, inputs, training=False):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        return self.dense4(x)

class MyModel20(tf.keras.Model):

    def __init__(self):
        super(MyModel, self).__init__()
        self.dense1 = tf.keras.layers.Dense(2, activation=tf.nn.tanh)
        
        self.dense2 = tf.keras.layers.Dense(20, activation=tf.nn.tanh)
        self.dense3 = tf.keras.layers.Dense(20, activation=tf.nn.tanh)
        self.dense4 = tf.keras.layers.Dense(20, activation=tf.nn.tanh)

        self.dense5 = tf.keras.layers.Dense(2, activation=tf.nn.tanh)

    def call(self, inputs, training=False):
        x = self.dense1(inputs)
        x = self.dense2(x)
        x = self.dense3(x)
        return self.dense4(x)

model10 = MyModel10()
model20 = MyModel20()

# %% [markdown]
# ## Decaying Learning Rate

# %%
# DECAYING LEARNING RATE
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr*tf.math.exp(-0.0001)
    
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# ### Checkpoints

# %%
checkpoint_path = "checkpoints/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 verbose=1)

# %%
model.compile(
    loss= tf.keras.losses.MeanSquaredError(),
    #optimizer=tfps.optimizers.bfgs_minimize(), #clipvalue = 0.001),
    #optimizer=keras.optimizers.SGD(0.00001), #, clipvalue = 0.001),
    optimizer=keras.optimizers.Adam(0.001), #, clipvalue = 0.001),
    metrics=["accuracy"],
)

# %%
#wandb.init()
start_time = time.time()
history = model.fit(train_dataset, epochs = 100, validation_data=val_dataset, callbacks=[callback, cp_callback], verbose=1)
print("running time : %s seconds" % (time.time() - start_time))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 199ms/step - loss: 0.2320 - accuracy: 0.6971 - val_loss: 0.2232 - val_accuracy: 0.7119
#
# Epoch 00001: val_loss improved from inf to 0.22319, saving model to checkpoints\cp.ckpt
# Epoch 2/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.2223 - accuracy: 0.7172 - val_loss: 0.2139 - val_accuracy: 0.7277
#
# Epoch 00002: val_loss improved from 0.22319 to 0.21392, saving model to checkpoints\cp.ckpt
# Epoch 3/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.2130 - accuracy: 0.7337 - val_loss: 0.2050 - val_accuracy: 0.7412
#
# Epoch 00003: val_loss improved from 0.21392 to 0.20496, saving model to checkpoints\cp.ckpt
# Epoch 4/100
# 2/2 [==============================] - 0s 105ms/step - loss: 0.2040 - accuracy: 0.7466 - val_loss: 0.1963 - val_accuracy: 0.7532
#
# Epoch 00004: val_loss improved from 0.20496 to 0.19629, saving model to checkpoints\cp.ckpt
# Epoch 5/100
# 2/2 [==============================] - 0s 109ms/step - loss: 0.1953 - accuracy: 0.7580 - val_loss: 0.1879 - val_accuracy: 0.7632
#
# Epoch 00005: val_loss improved from 0.19629 to 0.18792, saving model to checkpoints\cp.ckpt
# Epoch 6/100
# 2/2 [==============================] - 0s 120ms/step - loss: 0.1870 - accuracy: 0.7675 - val_loss: 0.1799 - val_accuracy: 0.7716
#
# Epoch 00006: val_loss improved from 0.18792 to 0.17988, saving model to checkpoints\cp.ckpt
# Epoch 7/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.1790 - accuracy: 0.7759 - val_loss: 0.1722 - val_accuracy: 0.7805
#
# Epoch 00007: val_loss improved from 0.17988 to 0.17220, saving model to checkpoints\cp.ckpt
# Epoch 8/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1713 - accuracy: 0.7830 - val_loss: 0.1649 - val_accuracy: 0.7874
#
# Epoch 00008: val_loss improved from 0.17220 to 0.16488, saving model to checkpoints\cp.ckpt
# Epoch 9/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.1639 - accuracy: 0.7894 - val_loss: 0.1579 - val_accuracy: 0.7933
#
# Epoch 00009: val_loss improved from 0.16488 to 0.15787, saving model to checkpoints\cp.ckpt
# Epoch 10/100
# 2/2 [==============================] - 0s 134ms/step - loss: 0.1569 - accuracy: 0.7951 - val_loss: 0.1511 - val_accuracy: 0.7987
#
# Epoch 00010: val_loss improved from 0.15787 to 0.15114, saving model to checkpoints\cp.ckpt
# Epoch 11/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.1502 - accuracy: 0.8005 - val_loss: 0.1447 - val_accuracy: 0.8040
#
# Epoch 00011: val_loss improved from 0.15114 to 0.14467, saving model to checkpoints\cp.ckpt
# Epoch 12/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.1437 - accuracy: 0.8048 - val_loss: 0.1385 - val_accuracy: 0.8078
#
# Epoch 00012: val_loss improved from 0.14467 to 0.13848, saving model to checkpoints\cp.ckpt
# Epoch 13/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.1376 - accuracy: 0.8091 - val_loss: 0.1326 - val_accuracy: 0.8123
#
# Epoch 00013: val_loss improved from 0.13848 to 0.13256, saving model to checkpoints\cp.ckpt
# Epoch 14/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1317 - accuracy: 0.8128 - val_loss: 0.1269 - val_accuracy: 0.8167
#
# Epoch 00014: val_loss improved from 0.13256 to 0.12691, saving model to checkpoints\cp.ckpt
# Epoch 15/100
# 2/2 [==============================] - 0s 114ms/step - loss: 0.1261 - accuracy: 0.8164 - val_loss: 0.1215 - val_accuracy: 0.8203
#
# Epoch 00015: val_loss improved from 0.12691 to 0.12151, saving model to checkpoints\cp.ckpt
# Epoch 16/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.1207 - accuracy: 0.8196 - val_loss: 0.1163 - val_accuracy: 0.8238
#
# Epoch 00016: val_loss improved from 0.12151 to 0.11633, saving model to checkpoints\cp.ckpt
# Epoch 17/100
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1155 - accuracy: 0.8223 - val_loss: 0.1114 - val_accuracy: 0.8270
#
# Epoch 00017: val_loss improved from 0.11633 to 0.11135, saving model to checkpoints\cp.ckpt
# Epoch 18/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.1105 - accuracy: 0.8251 - val_loss: 0.1066 - val_accuracy: 0.8305
#
# Epoch 00018: val_loss improved from 0.11135 to 0.10658, saving model to checkpoints\cp.ckpt
# Epoch 19/100
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1058 - accuracy: 0.8277 - val_loss: 0.1020 - val_accuracy: 0.8330
#
# Epoch 00019: val_loss improved from 0.10658 to 0.10201, saving model to checkpoints\cp.ckpt
# Epoch 20/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1012 - accuracy: 0.8307 - val_loss: 0.0976 - val_accuracy: 0.8355
#
# Epoch 00020: val_loss improved from 0.10201 to 0.09763, saving model to checkpoints\cp.ckpt
# Epoch 21/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0969 - accuracy: 0.8330 - val_loss: 0.0934 - val_accuracy: 0.8375
#
# Epoch 00021: val_loss improved from 0.09763 to 0.09344, saving model to checkpoints\cp.ckpt
# Epoch 22/100
# 2/2 [==============================] - 0s 137ms/step - loss: 0.0927 - accuracy: 0.8353 - val_loss: 0.0894 - val_accuracy: 0.8389
#
# Epoch 00022: val_loss improved from 0.09344 to 0.08943, saving model to checkpoints\cp.ckpt
# Epoch 23/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0887 - accuracy: 0.8375 - val_loss: 0.0856 - val_accuracy: 0.8410
#
# Epoch 00023: val_loss improved from 0.08943 to 0.08558, saving model to checkpoints\cp.ckpt
# Epoch 24/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0849 - accuracy: 0.8396 - val_loss: 0.0819 - val_accuracy: 0.8428
#
# Epoch 00024: val_loss improved from 0.08558 to 0.08189, saving model to checkpoints\cp.ckpt
# Epoch 25/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0812 - accuracy: 0.8417 - val_loss: 0.0784 - val_accuracy: 0.8437
#
# Epoch 00025: val_loss improved from 0.08189 to 0.07835, saving model to checkpoints\cp.ckpt
# Epoch 26/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0777 - accuracy: 0.8437 - val_loss: 0.0750 - val_accuracy: 0.8451
#
# Epoch 00026: val_loss improved from 0.07835 to 0.07497, saving model to checkpoints\cp.ckpt
# Epoch 27/100
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0744 - accuracy: 0.8460 - val_loss: 0.0717 - val_accuracy: 0.8470
#
# Epoch 00027: val_loss improved from 0.07497 to 0.07173, saving model to checkpoints\cp.ckpt
# Epoch 28/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0712 - accuracy: 0.8479 - val_loss: 0.0686 - val_accuracy: 0.8483
#
# Epoch 00028: val_loss improved from 0.07173 to 0.06862, saving model to checkpoints\cp.ckpt
# Epoch 29/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0681 - accuracy: 0.8498 - val_loss: 0.0657 - val_accuracy: 0.8497
#
# Epoch 00029: val_loss improved from 0.06862 to 0.06565, saving model to checkpoints\cp.ckpt
# Epoch 30/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0651 - accuracy: 0.8515 - val_loss: 0.0628 - val_accuracy: 0.8514
#
# Epoch 00030: val_loss improved from 0.06565 to 0.06280, saving model to checkpoints\cp.ckpt
# Epoch 31/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0623 - accuracy: 0.8531 - val_loss: 0.0601 - val_accuracy: 0.8533
#
# Epoch 00031: val_loss improved from 0.06280 to 0.06007, saving model to checkpoints\cp.ckpt
# Epoch 32/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0596 - accuracy: 0.8548 - val_loss: 0.0575 - val_accuracy: 0.8552
#
# Epoch 00032: val_loss improved from 0.06007 to 0.05746, saving model to checkpoints\cp.ckpt
# Epoch 33/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0570 - accuracy: 0.8565 - val_loss: 0.0550 - val_accuracy: 0.8571
#
# Epoch 00033: val_loss improved from 0.05746 to 0.05497, saving model to checkpoints\cp.ckpt
# Epoch 34/100
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0546 - accuracy: 0.8582 - val_loss: 0.0526 - val_accuracy: 0.8594
#
# Epoch 00034: val_loss improved from 0.05497 to 0.05258, saving model to checkpoints\cp.ckpt
# Epoch 35/100
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0522 - accuracy: 0.8598 - val_loss: 0.0503 - val_accuracy: 0.8606
#
# Epoch 00035: val_loss improved from 0.05258 to 0.05030, saving model to checkpoints\cp.ckpt
# Epoch 36/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0499 - accuracy: 0.8615 - val_loss: 0.0481 - val_accuracy: 0.8620
#
# Epoch 00036: val_loss improved from 0.05030 to 0.04812, saving model to checkpoints\cp.ckpt
# Epoch 37/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0478 - accuracy: 0.8631 - val_loss: 0.0460 - val_accuracy: 0.8642
#
# Epoch 00037: val_loss improved from 0.04812 to 0.04603, saving model to checkpoints\cp.ckpt
# Epoch 38/100
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0457 - accuracy: 0.8646 - val_loss: 0.0440 - val_accuracy: 0.8657
#
# Epoch 00038: val_loss improved from 0.04603 to 0.04404, saving model to checkpoints\cp.ckpt
# Epoch 39/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0437 - accuracy: 0.8662 - val_loss: 0.0421 - val_accuracy: 0.8674
#
# Epoch 00039: val_loss improved from 0.04404 to 0.04215, saving model to checkpoints\cp.ckpt
# Epoch 40/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0419 - accuracy: 0.8680 - val_loss: 0.0403 - val_accuracy: 0.8689
#
# Epoch 00040: val_loss improved from 0.04215 to 0.04034, saving model to checkpoints\cp.ckpt
# Epoch 41/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0401 - accuracy: 0.8695 - val_loss: 0.0386 - val_accuracy: 0.8705
#
# Epoch 00041: val_loss improved from 0.04034 to 0.03861, saving model to checkpoints\cp.ckpt
# Epoch 42/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0384 - accuracy: 0.8711 - val_loss: 0.0370 - val_accuracy: 0.8727
#
# Epoch 00042: val_loss improved from 0.03861 to 0.03697, saving model to checkpoints\cp.ckpt
# Epoch 43/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0367 - accuracy: 0.8727 - val_loss: 0.0354 - val_accuracy: 0.8741
#
# Epoch 00043: val_loss improved from 0.03697 to 0.03541, saving model to checkpoints\cp.ckpt
# Epoch 44/100
# 2/2 [==============================] - 0s 135ms/step - loss: 0.0352 - accuracy: 0.8744 - val_loss: 0.0339 - val_accuracy: 0.8749
#
# Epoch 00044: val_loss improved from 0.03541 to 0.03393, saving model to checkpoints\cp.ckpt
# Epoch 45/100
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0337 - accuracy: 0.8759 - val_loss: 0.0325 - val_accuracy: 0.8765
#
# Epoch 00045: val_loss improved from 0.03393 to 0.03253, saving model to checkpoints\cp.ckpt
# Epoch 46/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0324 - accuracy: 0.8773 - val_loss: 0.0312 - val_accuracy: 0.8776
#
# Epoch 00046: val_loss improved from 0.03253 to 0.03120, saving model to checkpoints\cp.ckpt
# Epoch 47/100
# 2/2 [==============================] - 0s 125ms/step - loss: 0.0310 - accuracy: 0.8788 - val_loss: 0.0299 - val_accuracy: 0.8798
#
# Epoch 00047: val_loss improved from 0.03120 to 0.02994, saving model to checkpoints\cp.ckpt
# Epoch 48/100
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0298 - accuracy: 0.8801 - val_loss: 0.0287 - val_accuracy: 0.8803
#
# Epoch 00048: val_loss improved from 0.02994 to 0.02875, saving model to checkpoints\cp.ckpt
# Epoch 49/100
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0286 - accuracy: 0.8817 - val_loss: 0.0276 - val_accuracy: 0.8813
#
# Epoch 00049: val_loss improved from 0.02875 to 0.02762, saving model to checkpoints\cp.ckpt
# Epoch 50/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0275 - accuracy: 0.8831 - val_loss: 0.0266 - val_accuracy: 0.8828
#
# Epoch 00050: val_loss improved from 0.02762 to 0.02656, saving model to checkpoints\cp.ckpt
# Epoch 51/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0265 - accuracy: 0.8845 - val_loss: 0.0256 - val_accuracy: 0.8842
#
# Epoch 00051: val_loss improved from 0.02656 to 0.02556, saving model to checkpoints\cp.ckpt
# Epoch 52/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0255 - accuracy: 0.8858 - val_loss: 0.0246 - val_accuracy: 0.8860
#
# Epoch 00052: val_loss improved from 0.02556 to 0.02462, saving model to checkpoints\cp.ckpt
# Epoch 53/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0245 - accuracy: 0.8872 - val_loss: 0.0237 - val_accuracy: 0.8872
#
# Epoch 00053: val_loss improved from 0.02462 to 0.02374, saving model to checkpoints\cp.ckpt
# Epoch 54/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0237 - accuracy: 0.8883 - val_loss: 0.0229 - val_accuracy: 0.8890
#
# Epoch 00054: val_loss improved from 0.02374 to 0.02291, saving model to checkpoints\cp.ckpt
# Epoch 55/100
# 2/2 [==============================] - 0s 138ms/step - loss: 0.0228 - accuracy: 0.8897 - val_loss: 0.0221 - val_accuracy: 0.8901
#
# Epoch 00055: val_loss improved from 0.02291 to 0.02213, saving model to checkpoints\cp.ckpt
# Epoch 56/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0221 - accuracy: 0.8910 - val_loss: 0.0214 - val_accuracy: 0.8913
#
# Epoch 00056: val_loss improved from 0.02213 to 0.02141, saving model to checkpoints\cp.ckpt
# Epoch 57/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0214 - accuracy: 0.8920 - val_loss: 0.0207 - val_accuracy: 0.8924
#
# Epoch 00057: val_loss improved from 0.02141 to 0.02073, saving model to checkpoints\cp.ckpt
# Epoch 58/100
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0207 - accuracy: 0.8933 - val_loss: 0.0201 - val_accuracy: 0.8932
#
# Epoch 00058: val_loss improved from 0.02073 to 0.02009, saving model to checkpoints\cp.ckpt
# Epoch 59/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0201 - accuracy: 0.8941 - val_loss: 0.0195 - val_accuracy: 0.8944
#
# Epoch 00059: val_loss improved from 0.02009 to 0.01950, saving model to checkpoints\cp.ckpt
# Epoch 60/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0195 - accuracy: 0.8952 - val_loss: 0.0190 - val_accuracy: 0.8963
#
# Epoch 00060: val_loss improved from 0.01950 to 0.01895, saving model to checkpoints\cp.ckpt
# Epoch 61/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0189 - accuracy: 0.8962 - val_loss: 0.0184 - val_accuracy: 0.8969
#
# Epoch 00061: val_loss improved from 0.01895 to 0.01844, saving model to checkpoints\cp.ckpt
# Epoch 62/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0184 - accuracy: 0.8973 - val_loss: 0.0180 - val_accuracy: 0.8984
#
# Epoch 00062: val_loss improved from 0.01844 to 0.01797, saving model to checkpoints\cp.ckpt
# Epoch 63/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0180 - accuracy: 0.8984 - val_loss: 0.0175 - val_accuracy: 0.8992
#
# Epoch 00063: val_loss improved from 0.01797 to 0.01753, saving model to checkpoints\cp.ckpt
# Epoch 64/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0175 - accuracy: 0.8992 - val_loss: 0.0171 - val_accuracy: 0.8998
#
# Epoch 00064: val_loss improved from 0.01753 to 0.01712, saving model to checkpoints\cp.ckpt
# Epoch 65/100
# 2/2 [==============================] - 0s 145ms/step - loss: 0.0171 - accuracy: 0.9003 - val_loss: 0.0167 - val_accuracy: 0.9009
#
# Epoch 00065: val_loss improved from 0.01712 to 0.01674, saving model to checkpoints\cp.ckpt
# Epoch 66/100
# 2/2 [==============================] - 0s 145ms/step - loss: 0.0168 - accuracy: 0.9013 - val_loss: 0.0164 - val_accuracy: 0.9014
#
# Epoch 00066: val_loss improved from 0.01674 to 0.01639, saving model to checkpoints\cp.ckpt
# Epoch 67/100
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0164 - accuracy: 0.9024 - val_loss: 0.0161 - val_accuracy: 0.9027
#
# Epoch 00067: val_loss improved from 0.01639 to 0.01607, saving model to checkpoints\cp.ckpt
# Epoch 68/100
# 2/2 [==============================] - 0s 136ms/step - loss: 0.0161 - accuracy: 0.9033 - val_loss: 0.0158 - val_accuracy: 0.9040
#
# Epoch 00068: val_loss improved from 0.01607 to 0.01577, saving model to checkpoints\cp.ckpt
# Epoch 69/100
# 2/2 [==============================] - 0s 142ms/step - loss: 0.0158 - accuracy: 0.9042 - val_loss: 0.0155 - val_accuracy: 0.9045
#
# Epoch 00069: val_loss improved from 0.01577 to 0.01550, saving model to checkpoints\cp.ckpt
# Epoch 70/100
# 2/2 [==============================] - 0s 129ms/step - loss: 0.0155 - accuracy: 0.9051 - val_loss: 0.0152 - val_accuracy: 0.9054
#
# Epoch 00070: val_loss improved from 0.01550 to 0.01524, saving model to checkpoints\cp.ckpt
# Epoch 71/100
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0153 - accuracy: 0.9059 - val_loss: 0.0150 - val_accuracy: 0.9060
#
# Epoch 00071: val_loss improved from 0.01524 to 0.01501, saving model to checkpoints\cp.ckpt
# Epoch 72/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.0150 - accuracy: 0.9064 - val_loss: 0.0148 - val_accuracy: 0.9064
#
# Epoch 00072: val_loss improved from 0.01501 to 0.01480, saving model to checkpoints\cp.ckpt
# Epoch 73/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0148 - accuracy: 0.9072 - val_loss: 0.0146 - val_accuracy: 0.9071
#
# Epoch 00073: val_loss improved from 0.01480 to 0.01460, saving model to checkpoints\cp.ckpt
# Epoch 74/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0146 - accuracy: 0.9077 - val_loss: 0.0144 - val_accuracy: 0.9079
#
# Epoch 00074: val_loss improved from 0.01460 to 0.01442, saving model to checkpoints\cp.ckpt
# Epoch 75/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0145 - accuracy: 0.9084 - val_loss: 0.0143 - val_accuracy: 0.9084
#
# Epoch 00075: val_loss improved from 0.01442 to 0.01426, saving model to checkpoints\cp.ckpt
# Epoch 76/100
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0143 - accuracy: 0.9091 - val_loss: 0.0141 - val_accuracy: 0.9089
#
# Epoch 00076: val_loss improved from 0.01426 to 0.01411, saving model to checkpoints\cp.ckpt
# Epoch 77/100
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0141 - accuracy: 0.9097 - val_loss: 0.0140 - val_accuracy: 0.9087
#
# Epoch 00077: val_loss improved from 0.01411 to 0.01397, saving model to checkpoints\cp.ckpt
# Epoch 78/100
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0140 - accuracy: 0.9102 - val_loss: 0.0138 - val_accuracy: 0.9090
#
# Epoch 00078: val_loss improved from 0.01397 to 0.01384, saving model to checkpoints\cp.ckpt
# Epoch 79/100
# 2/2 [==============================] - 0s 140ms/step - loss: 0.0139 - accuracy: 0.9106 - val_loss: 0.0137 - val_accuracy: 0.9091
#
# Epoch 00079: val_loss improved from 0.01384 to 0.01373, saving model to checkpoints\cp.ckpt
# Epoch 80/100
# 2/2 [==============================] - 0s 143ms/step - loss: 0.0138 - accuracy: 0.9111 - val_loss: 0.0136 - val_accuracy: 0.9096
#
# Epoch 00080: val_loss improved from 0.01373 to 0.01362, saving model to checkpoints\cp.ckpt
# Epoch 81/100
# 2/2 [==============================] - 0s 126ms/step - loss: 0.0137 - accuracy: 0.9115 - val_loss: 0.0135 - val_accuracy: 0.9100
#
# Epoch 00081: val_loss improved from 0.01362 to 0.01353, saving model to checkpoints\cp.ckpt
# Epoch 82/100
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0136 - accuracy: 0.9120 - val_loss: 0.0134 - val_accuracy: 0.9107
#
# Epoch 00082: val_loss improved from 0.01353 to 0.01344, saving model to checkpoints\cp.ckpt
# Epoch 83/100
# 2/2 [==============================] - 0s 130ms/step - loss: 0.0135 - accuracy: 0.9123 - val_loss: 0.0134 - val_accuracy: 0.9112
#
# Epoch 00083: val_loss improved from 0.01344 to 0.01336, saving model to checkpoints\cp.ckpt
# Epoch 84/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0134 - accuracy: 0.9129 - val_loss: 0.0133 - val_accuracy: 0.9122
#
# Epoch 00084: val_loss improved from 0.01336 to 0.01329, saving model to checkpoints\cp.ckpt
# Epoch 85/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0133 - accuracy: 0.9134 - val_loss: 0.0132 - val_accuracy: 0.9125
#
# Epoch 00085: val_loss improved from 0.01329 to 0.01323, saving model to checkpoints\cp.ckpt
# Epoch 86/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0133 - accuracy: 0.9136 - val_loss: 0.0132 - val_accuracy: 0.9129
#
# Epoch 00086: val_loss improved from 0.01323 to 0.01317, saving model to checkpoints\cp.ckpt
# Epoch 87/100
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0132 - accuracy: 0.9142 - val_loss: 0.0131 - val_accuracy: 0.9134
#
# Epoch 00087: val_loss improved from 0.01317 to 0.01311, saving model to checkpoints\cp.ckpt
# Epoch 88/100
# 2/2 [==============================] - 0s 145ms/step - loss: 0.0132 - accuracy: 0.9145 - val_loss: 0.0131 - val_accuracy: 0.9132
#
# Epoch 00088: val_loss improved from 0.01311 to 0.01307, saving model to checkpoints\cp.ckpt
# Epoch 89/100
# 2/2 [==============================] - 0s 144ms/step - loss: 0.0131 - accuracy: 0.9147 - val_loss: 0.0130 - val_accuracy: 0.9137
#
# Epoch 00089: val_loss improved from 0.01307 to 0.01302, saving model to checkpoints\cp.ckpt
# Epoch 90/100
# 2/2 [==============================] - 0s 139ms/step - loss: 0.0131 - accuracy: 0.9150 - val_loss: 0.0130 - val_accuracy: 0.9137
#
# Epoch 00090: val_loss improved from 0.01302 to 0.01298, saving model to checkpoints\cp.ckpt
# Epoch 91/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.0130 - accuracy: 0.9152 - val_loss: 0.0129 - val_accuracy: 0.9136
#
# Epoch 00091: val_loss improved from 0.01298 to 0.01295, saving model to checkpoints\cp.ckpt
# Epoch 92/100
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0130 - accuracy: 0.9154 - val_loss: 0.0129 - val_accuracy: 0.9137
#
# Epoch 00092: val_loss improved from 0.01295 to 0.01292, saving model to checkpoints\cp.ckpt
# Epoch 93/100
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0130 - accuracy: 0.9157 - val_loss: 0.0129 - val_accuracy: 0.9141
#
# Epoch 00093: val_loss improved from 0.01292 to 0.01289, saving model to checkpoints\cp.ckpt
# Epoch 94/100
# 2/2 [==============================] - 0s 132ms/step - loss: 0.0129 - accuracy: 0.9161 - val_loss: 0.0129 - val_accuracy: 0.9143
#
# Epoch 00094: val_loss improved from 0.01289 to 0.01286, saving model to checkpoints\cp.ckpt
# Epoch 95/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0129 - accuracy: 0.9164 - val_loss: 0.0128 - val_accuracy: 0.9149
#
# Epoch 00095: val_loss improved from 0.01286 to 0.01284, saving model to checkpoints\cp.ckpt
# Epoch 96/100
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0129 - accuracy: 0.9166 - val_loss: 0.0128 - val_accuracy: 0.9152
#
# Epoch 00096: val_loss improved from 0.01284 to 0.01282, saving model to checkpoints\cp.ckpt
# Epoch 97/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0129 - accuracy: 0.9167 - val_loss: 0.0128 - val_accuracy: 0.9155
#
# Epoch 00097: val_loss improved from 0.01282 to 0.01280, saving model to checkpoints\cp.ckpt
# Epoch 98/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0128 - accuracy: 0.9170 - val_loss: 0.0128 - val_accuracy: 0.9158
#
# Epoch 00098: val_loss improved from 0.01280 to 0.01278, saving model to checkpoints\cp.ckpt
# Epoch 99/100
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0128 - accuracy: 0.9171 - val_loss: 0.0128 - val_accuracy: 0.9158
#
# Epoch 00099: val_loss improved from 0.01278 to 0.01276, saving model to checkpoints\cp.ckpt
# Epoch 100/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.0128 - accuracy: 0.9174 - val_loss: 0.0127 - val_accuracy: 0.9162
#
# Epoch 00100: val_loss improved from 0.01276 to 0.01275, saving model to checkpoints\cp.ckpt
# running time : 31.856292009353638 seconds

# %%
plt.figure(figsize = (10,5))
plt.plot(history.history["loss"])
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.title(r'Reversible Composition of H\'enon Maps', fontsize = 30)
plt.xlabel(r'epochs', fontsize=20)
plt.ylabel(r'loss', fontsize=20)
plt.yscale("log")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(axis='both', alpha=.3)
plt.savefig("loss_Henon_E01667")

# %% [markdown]
# # Tests

# %%
start_time = time.time()

#x0 = np.array([[0.025, 0.],[0.08, 0.],[0.085, 0.],[0.09, 0.],[0.095, 0.],[0.15, 0.],[0.1, -0.07],[0.1, -0.04],[0.1, 0.01],[0.1, 0.08],[0.1, 0.075]])
x0 = np.array([[rd.randrange(-100, 100, 1)*0.001,rd.randrange(-100, 100, 1)*0.001] for _ in range(10)])
iterations = [model(x0)]
for _ in range(200):
    iterations.append(model(iterations[-1]))

print("running time : %s seconds" % (time.time() - start_time))

# %%
plt.figure(figsize=(10,10))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.title(r'Reversible Composition of H\'enon Maps', fontsize = 25)

for i in iterations:
    plt.scatter(*zip(*i.numpy()), s=1, linewidth=0)
    
plt.scatter(*zip(*x0), s=15, linewidth=0)

#plt.scatter([i[0] for i in Poincare_points], [i[1] for i in Poincare_points], linewidth = 0, s=2)

plt.xlabel(r'$x$', fontsize=28, labelpad=8)
plt.ylabel(r'$y$', fontsize=28, labelpad=15)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(axis='both', alpha=.3)
plt.show()

# %%
model(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bd0200007a4a> in <module>
# ----> 1 model(x)
#
# NameError: name 'model' is not defined

# %%
plt.figure(figsize=(10,10))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.title(r'Composition of H\'enon Maps', fontsize = 30)
plt.scatter(Ty,Tydot, color = "b", label = r'target, $x$', linewidth = 1, s=2)
plt.scatter(*zip(*test.numpy()), color = "r", label = r'$\mathcal{T}^{2}(x)$, learned', linewidth = 1, s=2)
plt.xlabel(r'$y$', fontsize=28, labelpad=8)
plt.ylabel(r'$p_{y}$', fontsize=28, labelpad=15)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(axis='both', alpha=.3)
plt.legend(fontsize = 25, loc = 'lower right')
#plt.savefig("Iterations_Henon_E0125")
plt.show()
