# %%
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Layer
from tensorflow.keras.regularizers import l2
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import random as rd
import sys

sys.path.append("..")

from AllMethods import ReversibleSymplecticNN as rs
from AllMethods import PerturbedPendulum_Methods as pp

#physical_devices = tf.config.list_physical_devices('GPU') 
#tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
d=4

file = open("X_train.txt", "r")
line_count = 0
for line in file:
    if line != "\n":
        line_count += 1
file.close()

x = []
read_x = open("X_train.txt", "r")

for i in range(int(line_count/d)):
    #8d
    #x.append([float(read_x.readline()), float(read_x.readline()), float(read_x.readline()), float(read_x.readline()), float(read_x.readline()), float(read_x.readline()), float(read_x.readline()), float(read_x.readline())])
    #4d
    x.append([float(read_x.readline()), float(read_x.readline()), float(read_x.readline()), float(read_x.readline())])

read_x.close()


y = []
read_y = open("Y_train.txt", "r")

for i in range(int(line_count/d)):
    #8d
    #y.append([float(read_y.readline()), float(read_y.readline()), float(read_y.readline()), float(read_y.readline()), float(read_y.readline()), float(read_y.readline()), float(read_y.readline()), float(read_y.readline())])
    #4d
    y.append([float(read_y.readline()), float(read_y.readline()), float(read_y.readline()), float(read_y.readline())])

read_y.close()

print("Number of points: ", len(x))
print("Number of points: ", len(y))
# Out:
# Number of points:  801

# %%
plt.figure(figsize=(10,5))
plt.plot(x[:400])
plt.show()

# %%
x_train = np.array(x[0:-1])
x_train = x_train.astype(np.float32)

y_train = np.array(x[1:])
y_train = y_train.astype(np.float32)

val_len = 1000

x_val = x_train[-val_len:]
y_val = y_train[-val_len:]

val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.batch(1000)

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.batch(1000)

# %%
class MLP(tf.keras.layers.Layer):
    
    def __init__(self):
        super(MLP, self).__init__()


    def build(self, input_shape):
        
        
        self.L1 = tf.keras.layers.Dense(50, activation='tanh')
        self.L2 = tf.keras.layers.Dense(50, activation='tanh')
        self.L3 = tf.keras.layers.Dense(4, activation='tanh')
        
    def call(self, inputs, training=False):
        
        h = self.L1(inputs)
        h = self.L2(h)
        h = self.L3(h)
        
        return h

# %%
class shift(tf.keras.layers.Layer):
    
    def __init__(self):

        super(shift, self).__init__()

    def build(self, input_shape):
        
        self.w = self.add_weight(
            name='w',
            shape=(4,),
            initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.01, seed=None),
            trainable = True
            )
            
        self.b = self.add_weight(
            name='b',
            shape=(4,),
            initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.01, seed=None),
            trainable = True
            )


    def call(self, inputs, training=False):
        
        return self.w*inputs + self.b

# %%
def get_shift_and_log_scale_resnet(input_shape, blocks, shift):
    
    inputs = tf.keras.Input(shape=input_shape)
    h = inputs

    for block in blocks:
        h = block(h)

    shift, log_scale = shift(inputs), h
    log_scale = tf.math.tanh(log_scale)
    return Model(inputs=inputs, outputs=[shift, log_scale], name='name')

# %%
class AffineCouplingLayer(layers.Layer):

    def __init__(self, shift_and_log_scale_fn, mask):
        
        super(AffineCouplingLayer, self).__init__()
        self.shift_and_log_scale_fn = shift_and_log_scale_fn
        self.b = tf.cast(mask, tf.float32)

    def call(self, x, inverse):
        
        if inverse == 1:
            t, log_s = self.shift_and_log_scale_fn(x * self.b)
            y = self.b * x + (1 - self.b) * (x * tf.exp(log_s) + t)
            return y
        
        if inverse == 0:
            t, log_s = self.shift_and_log_scale_fn(x * self.b)
            y = self.b * x + (1 - self.b) * ((x - t) * tf.exp(-log_s))
            return y

# %%
class R(tf.keras.layers.Layer):

    def __init__(self):
        super(R, self).__init__()
        
    def call(self, inputs):
    
    #8d
        #return inputs*tf.constant([[1., 1., 1., 1., -1., -1., -1., -1.]])
    #4d
        return inputs*tf.constant([[1., 1., -1., -1.]])

# %%
class RealNVPModel(tf.keras.Model):
    
    def __init__(self, shift_and_log_scale, **kwargs):
        
        super(RealNVPModel, self).__init__()
        self.R = R()
        masks = []
        self.l = []
        
        for j in range(len(shift_and_log_scale)):
            
            if j%4==0:
                masks.append(tf.constant([[1., 0., 1., 0.]]))
            if j%4==1:
                masks.append(tf.constant([[0., 1., 0., 1.]]))
            if j%4==2:
                masks.append(tf.constant([[1., 0., 1., 0.]]))
            if j%4==3:
                masks.append(tf.constant([[0., 1., 0., 1.]]))

        
        for i,j in zip(shift_and_log_scale, masks):
            self.l.append(AffineCouplingLayer(i, j))
        

    def call(self, input_tensor):
        
        a = self.R(input_tensor)
        
        for layer in self.l:
            a = layer._forward(a)

        a = self.R(a)

        for layer in self.l[::-1]:
            a = layer._inverse(a)
        
        return a
    

"""8d
            if j%8==0:
                masks.append(tf.constant([[0., 0., 0., 0., 1., 1., 1., 1.]]))
            if j%8==1:
                masks.append(tf.constant([[1., 0., 0., 0., 0., 1., 1., 1.]]))
            if j%8==2:
                masks.append(tf.constant([[1., 1., 0., 0., 0., 0., 1., 1.]]))
            if j%8==3:
                masks.append(tf.constant([[1., 1., 1., 0., 0., 0., 0., 1.]]))
            if j%8==4:
                masks.append(tf.constant([[1., 1., 1., 1., 0., 0., 0., 0.]]))
            if j%8==5:
                masks.append(tf.constant([[0., 1., 1., 1., 1., 0., 0., 0.]]))
            if j%8==6:
                masks.append(tf.constant([[0., 0., 1., 1., 1., 1., 0., 0.]]))
            if j%8==7:
                masks.append(tf.constant([[0., 0., 0., 1., 1., 1., 1., 0.]]))
""";

# %%
num_blocks = 6

blocks = [MLP() for i in range(num_blocks)]

#shifts = [shift() for i in range(len(blocks))]
shifts = [MLP() for i in range(len(blocks))]

shift_and_log_scale = [get_shift_and_log_scale_resnet((4), [i], j) for i,j in zip(blocks, shifts)]

model = RealNVPModel(shift_and_log_scale)

# %%
shift_and_log_scale[0].summary()
model(x_train)
model.summary()
# Out:
# Model: "name"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# mlp (MLP)                       (None, 8)            3408        input_1[0][0]
# __________________________________________________________________________________________________
# mlp_8 (MLP)                     (None, 8)            3408        input_1[0][0]
# __________________________________________________________________________________________________
# tf.math.tanh (TFOpLambda)       (None, 8)            0           mlp[0][0]
# ==================================================================================================
# Total params: 6,816
# Trainable params: 6,816
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model = RealNVPModel(shift_and_log_scale)
model(x_train)
# Out:
# <tf.Tensor: shape=(800, 8), dtype=float32, numpy=
# array([[-4.62251157e-03, -2.44375803e-02,  1.27816256e-02, ...,
#          6.66367309e-03, -3.23187560e-02,  2.88980193e-02],
#        [-5.26633337e-02, -3.54044745e-03,  1.06770515e-01, ...,
#          1.57538310e-01, -3.28518227e-02, -1.13032535e-02],
#        [-7.83106014e-02,  3.47844847e-02,  1.46127939e-01, ...,
#          2.53881842e-01, -3.72904382e-04, -5.61331138e-02],
#        ...,
#        [ 5.17702699e-02,  5.49383698e+01, -8.57396781e-01, ...,
#          7.54846096e+00,  5.19496822e+00, -3.92915964e+00],
#        [ 5.58225028e-02,  5.49619713e+01, -8.55002880e-01, ...,
#          7.52541018e+00,  5.20314503e+00, -3.95126677e+00],
#        [ 5.85586764e-02,  5.49572334e+01, -8.52848291e-01, ...,
#          7.48837185e+00,  5.20674992e+00, -3.96738744e+00]], dtype=float32)>

# %%
# DECAYING LEARNING RATE
def scheduler(epoch, lr):
    if epoch < 5:
        print(lr)
        return lr
    else:
        #print(lr)
        return lr*tf.math.exp(-0.0002)
    
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
lr = [0.002]
for i in range(10000):
    lr.append(scheduler(i, lr[-1]))

plt.plot(lr)
plt.show()
# Out:
# 0.002
# 0.002
# 0.002
# 0.002
# 0.002

# %%
model.compile(
    loss= tf.keras.losses.MeanSquaredError(),
    #loss = custom_loss,
    #optimizer=tfps.optimizers.bfgs_minimize(), #clipvalue = 0.001),
    #optimizer=keras.optimizers.SGD(0.00001), #, clipvalue = 0.001),
    optimizer=tf.keras.optimizers.Adam(0.002), #, clipvalue = 0.001),
    metrics=["accuracy"],
)

# %%
history = model.fit(train_dataset, epochs = 10, callbacks = [callback], verbose=1)
# Out:
# Epoch 1/10
# 0.0020000000949949026
# 1/1 [==============================] - 6s 6s/step - loss: 73.3646 - accuracy: 0.4238
# Epoch 2/10
# 0.0020000000949949026
# 1/1 [==============================] - 0s 195ms/step - loss: 13.1079 - accuracy: 0.1675
# Epoch 3/10
# 0.0020000000949949026
# 1/1 [==============================] - 0s 199ms/step - loss: 11.2499 - accuracy: 0.0000e+00
# Epoch 4/10
# 0.0020000000949949026
# 1/1 [==============================] - 0s 195ms/step - loss: 7.9342 - accuracy: 0.0000e+00
# Epoch 5/10
# 0.0020000000949949026
# 1/1 [==============================] - 0s 213ms/step - loss: 5.4347 - accuracy: 0.0000e+00
# Epoch 6/10
# 1/1 [==============================] - 0s 199ms/step - loss: 4.5405 - accuracy: 0.0000e+00
# Epoch 7/10
# 1/1 [==============================] - 0s 195ms/step - loss: 3.9975 - accuracy: 0.0000e+00
# Epoch 8/10
# 1/1 [==============================] - 0s 190ms/step - loss: 3.4810 - accuracy: 0.0000e+00
# Epoch 9/10
# 1/1 [==============================] - 0s 79ms/step - loss: 3.1210 - accuracy: 0.2975
# Epoch 10/10
# 1/1 [==============================] - 0s 62ms/step - loss: 2.9888 - accuracy: 0.2988

# %%
model.trainable_weights
# Out:
# [<tf.Variable 'shift/w:0' shape=(3,) dtype=float32, numpy=array([ 0.00160807, -0.00416988,  0.0148584 ], dtype=float32)>,
#  <tf.Variable 'shift/b:0' shape=(3,) dtype=float32, numpy=array([0.08967435, 0.0024099 , 0.01236125], dtype=float32)>,
#  <tf.Variable 'mlp/dense/kernel:0' shape=(3, 50) dtype=float32, numpy=
#  array([[ 0.12994781,  0.13906929, -0.05903667, -0.07194436,  0.23437294,
#          -0.3125073 ,  0.1325871 ,  0.24042806,  0.26857117,  0.2759789 ,
#           0.00044778, -0.11839184,  0.03275627, -0.1036288 ,  0.15231746,
#           0.23216292, -0.2486043 ,  0.30222335, -0.1447139 ,  0.20807174,
#           0.31430098,  0.10969937,  0.22058555,  0.24301043,  0.2513537 ,
#          -0.33220753, -0.05605021,  0.14434376,  0.30114016,  0.07296681,
#           0.09728876, -0.31317055,  0.26473853,  0.30515614, -0.17932202,
#          -0.1062831 ,  0.03429559, -0.03662875, -0.20384789, -0.32834795,
#           0.04421774,  0.2563242 , -0.3022054 , -0.31707498,  0.2411944 ,
#           0.15714031, -0.18097782,  0.24990222,  0.10865334,  0.21689025],
#         [-0.00463364,  0.01762754,  0.31559378, -0.14744028, -0.02680325,
#          -0.21809681,  0.0692191 ,  0.10795033,  0.27534512,  0.17013998,
#          -0.22946414, -0.29085267, -0.20714982, -0.25013283, -0.0350101 ,
#          -0.24736449,  0.30631623,  0.14683639, -0.22556917,  0.24636896,
#          -0.09145033,  0.26552278,  0.31152633, -0.02746588,  0.34026402,
#          -0.28087762, -0.28413665, -0.11070032, -0.21863541, -0.2501592 ,
#           0.21061026, -0.10382947,  0.2677795 ,  0.04058653, -0.26788926,
#           0.20801067, -0.22876064,  0.19034235, -0.28106016,  0.14327072,
#           0.09808291, -0.12042787,  0.2761492 ,  0.1381234 , -0.04383982,
#          -0.15456666, -0.06054115,  0.31348088, -0.26898292,  0.2755948 ],
#         [ 0.21459338, -0.10132498, -0.11920451,  0.05792584,  0.2179788 ,
#          -0.11547353, -0.03450381,  0.11526766,  0.27727842,  0.07084004,
#          -0.32967925, -0.30644393,  0.01023531, -0.06059346, -0.15044022,
#           0.28636774, -0.31619483,  0.09734643, -0.2816877 , -0.15955065,
#          -0.27413872,  0.13875136,  0.10975834, -0.25462046, -0.00491271,
#          -0.20492679,  0.05870647,  0.33417693, -0.21435441, -0.38189954,
#          -0.08872894, -0.12327442, -0.09931784, -0.2628013 ,  0.08933406,
#          -0.14134616, -0.08243566, -0.04527043,  0.22839183, -0.00349885,
#          -0.03708353,  0.05433891,  0.03533194, -0.1134088 ,  0.02973612,
#           0.17672132, -0.02115262, -0.3127648 , -0.2518576 ,  0.22793636]],
#        dtype=float32)>,
#  <tf.Variable 'mlp/dense/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-0.07805688, -0.0477777 , -0.08662041, -0.04526386, -0.10380749,
#          0.06385314,  0.01442483, -0.01769388, -0.05876388,  0.0039398 ,
#         -0.04963443,  0.08239557,  0.04618609,  0.0689492 ,  0.11221322,
#          0.08863028,  0.07238647, -0.07912429, -0.06697326,  0.07857538,
#          0.05347768, -0.06814646,  0.069838  ,  0.0673297 , -0.141327  ,
#         -0.05353094, -0.04960737, -0.07474878,  0.07018586, -0.05127867,
#          0.05479534, -0.0411104 , -0.05161374,  0.05925179, -0.07675621,
#          0.07704938,  0.08188204, -0.07020167,  0.08514369, -0.06727939,
#          0.04458821, -0.05167288, -0.07207473,  0.07497491,  0.04047171,
#         -0.06827781,  0.14414231,  0.07169639,  0.05834262, -0.06724854],
#        dtype=float32)>,
#  <tf.Variable 'mlp/dense_1/kernel:0' shape=(50, 50) dtype=float32, numpy=
#  array([[-0.08246072,  0.10878086, -0.13850941, ...,  0.11979872,
#           0.13275704,  0.07830101],
#         [ 0.09180702, -0.12429604,  0.11248565, ..., -0.20875846,
#           0.16650076, -0.17700292],
#         [ 0.10767131,  0.0642723 , -0.09343109, ..., -0.20722881,
#          -0.11949224, -0.21108611],
#         ...,
#         [-0.02310778, -0.16716275, -0.16812794, ...,  0.07201372,
#           0.05094125, -0.10564729],
#         [-0.18707156,  0.06216639, -0.22102141, ..., -0.24539785,
#          -0.13711174,  0.16723226],
#         [ 0.22645138, -0.17832272, -0.04096223, ...,  0.07290364,
#          -0.06970751,  0.0498965 ]], dtype=float32)>,
#  <tf.Variable 'mlp/dense_1/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-0.03710264, -0.03098365, -0.0301705 ,  0.05117448, -0.04145751,
#         -0.04562309,  0.03271526,  0.04678025,  0.03133069, -0.0248905 ,
#          0.03331501, -0.04302709, -0.03048612, -0.04548351,  0.03070924,
#         -0.05766926, -0.04032089, -0.03612645, -0.05255012, -0.05427386,
#         -0.05548042, -0.04305663,  0.0362496 ,  0.03738961, -0.06674787,
#         -0.0286662 , -0.04143681,  0.03346779, -0.03605042, -0.03287061,
#          0.03268909,  0.0435963 ,  0.04213255,  0.03497654, -0.04412953,
#         -0.04277555,  0.0496425 , -0.03211555,  0.05137927,  0.0424204 ,
#          0.05757562, -0.05282915,  0.0452058 , -0.05046215, -0.03270113,
#          0.04035407,  0.0326403 , -0.032743  ,  0.05265551,  0.03559051],
#        dtype=float32)>,
#  <tf.Variable 'mlp/dense_2/kernel:0' shape=(50, 3) dtype=float32, numpy=
#  array([[ 0.06400403, -0.13073468, -0.15618065],
#         [ 0.26683596, -0.19998679,  0.29909292],
#         [ 0.2764182 ,  0.15840328, -0.13929951],
#         [-0.08310726,  0.22813335,  0.3086227 ],
#         [ 0.22916113, -0.3278338 ,  0.2606767 ],
#         [ 0.04983352, -0.04970792,  0.24534604],
#         [-0.23339628,  0.21574262,  0.31559446],
#         [-0.31184298, -0.20388952, -0.24893984],
#         [-0.2561423 ,  0.28653255,  0.01968738],
#         [ 0.01007004,  0.04449946, -0.02494636],
#         [-0.04476592,  0.31700864, -0.17854294],
#         [ 0.30498406, -0.24210286, -0.22611102],
#         [ 0.10114937,  0.22401288,  0.04158717],
#         [ 0.22460212,  0.16516015,  0.21069524],
#         [-0.0728235 ,  0.06886995, -0.1775126 ],
#         [ 0.33963042, -0.06924513,  0.25808057],
#         [ 0.11796615,  0.1731104 , -0.22135338],
#         [ 0.17009398, -0.14541093,  0.05900925],
#         [ 0.22140057,  0.17517373,  0.04981664],
#         [ 0.3146041 , -0.14492592,  0.19874015],
#         [ 0.15345193,  0.28911158,  0.2244061 ],
#         [ 0.08865256, -0.17286406, -0.3070135 ],
#         [-0.32005882, -0.2500683 , -0.26240063],
#         [-0.02724508, -0.2372298 ,  0.1861783 ],
#         [ 0.32860357, -0.0078496 , -0.30189192],
#         [-0.00680511, -0.06171793,  0.06458881],
#         [ 0.3163452 , -0.28717595, -0.05904424],
#         [-0.21406084,  0.18519005, -0.03389424],
#         [ 0.09383355, -0.05945086, -0.17009033],
#         [ 0.04896519,  0.27850738, -0.22032064],
#         [-0.3240847 , -0.27048463,  0.1971322 ],
#         [-0.06824139, -0.00851399,  0.09133098],
#         [-0.07431144, -0.11193316,  0.17927662],
#         [-0.21001926, -0.01787418, -0.2519974 ],
#         [ 0.26530346, -0.15503536,  0.15892607],
#         [ 0.16797718, -0.04185489, -0.27370757],
#         [-0.08173127,  0.1527035 , -0.13060874],
#         [ 0.13890132,  0.05720279,  0.25384334],
#         [-0.01497549, -0.2910673 ,  0.05255482],
#         [-0.03679318, -0.29559842, -0.08483836],
#         [-0.19787264,  0.16549495,  0.14615664],
#         [ 0.07725532,  0.15990019, -0.16618566],
#         [-0.06882633, -0.01864654, -0.1554107 ],
#         [ 0.15072039, -0.2881426 ,  0.30343816],
#         [ 0.13482533, -0.20420125,  0.07178229],
#         [-0.27236503, -0.02902985,  0.07299072],
#         [-0.2752329 , -0.04309186, -0.26607537],
#         [ 0.091956  , -0.08179003,  0.3337159 ],
#         [-0.3324673 , -0.24534924,  0.10177621],
#         [-0.32257807,  0.00498673, -0.00653809]], dtype=float32)>,
#  <tf.Variable 'mlp/dense_2/bias:0' shape=(3,) dtype=float32, numpy=array([-0.03004501,  0.        ,  0.        ], dtype=float32)>,
#  <tf.Variable 'shift_1/w:0' shape=(3,) dtype=float32, numpy=array([ 0.00758833, -0.01335132,  0.01033415], dtype=float32)>,
#  <tf.Variable 'shift_1/b:0' shape=(3,) dtype=float32, numpy=array([ 0.00031135, -0.0159813 ,  0.01130117], dtype=float32)>,
#  <tf.Variable 'mlp_1/dense/kernel:0' shape=(3, 50) dtype=float32, numpy=
#  array([[-0.04764469,  0.21225634,  0.01841045, -0.27993265, -0.13760754,
#          -0.02843777,  0.10851646, -0.2846942 ,  0.0689226 ,  0.07152158,
#           0.32864282,  0.1562807 , -0.0461476 ,  0.13496672, -0.27106407,
#           0.01036602, -0.08340161, -0.12366041, -0.05254209,  0.143171  ,
#           0.30162665, -0.23807992, -0.02052542, -0.2731862 , -0.28696135,
#          -0.22679883, -0.29672223, -0.3406353 , -0.20244166, -0.12747738,
#          -0.21224427, -0.27556086,  0.17377473,  0.27656245,  0.08026391,
#           0.24648012, -0.03696813, -0.19735827,  0.2908066 ,  0.07033813,
#           0.0236642 , -0.12092176,  0.19374306,  0.22485521, -0.00436605,
#           0.08250692,  0.14403363,  0.2171285 ,  0.0921227 ,  0.06565432],
#         [-0.18378043, -0.2541686 ,  0.20810455,  0.21368487,  0.29446244,
#           0.06751135,  0.17382102, -0.10321278, -0.06646436, -0.31464726,
#          -0.31978938,  0.24188052, -0.17559321,  0.17170219, -0.06803676,
#          -0.07222492, -0.12568688, -0.12456568,  0.14397892, -0.31571093,
#          -0.1897655 , -0.27938947, -0.3112507 ,  0.0709426 , -0.22550112,
#           0.2739849 , -0.03789661,  0.20093633, -0.00220138,  0.01974955,
#           0.1329589 ,  0.12555905,  0.24181737, -0.0371482 ,  0.1630691 ,
#          -0.02415422, -0.22186072,  0.20081694, -0.23080246,  0.18513231,
#          -0.0632356 ,  0.34674087,  0.34819356, -0.02463613,  0.2770727 ,
#           0.10235507,  0.08343262,  0.14122105, -0.28679952,  0.32858747],
#         [ 0.22723034, -0.20822641,  0.10785386, -0.19185513, -0.29299507,
#          -0.07841721,  0.23156068, -0.28622985,  0.25114384,  0.17581227,
#          -0.16290687, -0.14916934,  0.28656146, -0.03464535, -0.26314905,
#           0.18720725,  0.3230181 ,  0.12639418, -0.3031994 ,  0.1790528 ,
#           0.161796  , -0.02671281, -0.31981608,  0.14741433, -0.19526805,
#           0.19709697, -0.03183094,  0.15533057,  0.28575322,  0.09772402,
#           0.10012892, -0.2538231 , -0.3208087 ,  0.04526845, -0.14796197,
#           0.17368904, -0.28885424, -0.05225086, -0.290294  ,  0.06612965,
#          -0.02947539,  0.2967668 , -0.1164479 ,  0.13180721, -0.19994499,
#           0.02210557,  0.30786487, -0.10443902,  0.22923598, -0.19562374]],
#        dtype=float32)>,
#  <tf.Variable 'mlp_1/dense/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-0.0206304 ,  0.02040032, -0.0197601 , -0.02770986, -0.01832677,
#          0.02801907,  0.02570951,  0.0249346 , -0.01048939, -0.07010962,
#         -0.03591193, -0.01203671,  0.00741979, -0.01529995,  0.00779439,
#         -0.00640424, -0.03786005,  0.02164496, -0.01955106,  0.0221472 ,
#          0.02368678, -0.01473881, -0.02334758,  0.02327594, -0.04733901,
#         -0.01952036, -0.00964552,  0.01204386, -0.0207033 , -0.01608265,
#         -0.06377229,  0.02894718,  0.03907882, -0.02618695, -0.00304481,
#         -0.0189616 ,  0.01953953,  0.01877751, -0.00377072,  0.0002998 ,
#          0.02399198, -0.02562183, -0.01163757, -0.02421059, -0.01105899,
#         -0.01933657, -0.01655176, -0.02451547,  0.01887292, -0.01369901],
#        dtype=float32)>,
#  <tf.Variable 'mlp_1/dense_1/kernel:0' shape=(50, 50) dtype=float32, numpy=
#  array([[-0.1724838 , -0.09185554, -0.08244715, ...,  0.15369432,
#          -0.03413241,  0.02696656],
#         [ 0.21629149, -0.18689325, -0.02369999, ...,  0.13311738,
#          -0.22639576, -0.23681307],
#         [-0.02703373,  0.21246953, -0.15201361, ..., -0.20129474,
#          -0.15952569,  0.07239579],
#         ...,
#         [-0.08893298, -0.04806658, -0.22373347, ...,  0.00086456,
#           0.15833744,  0.09239269],
#         [ 0.11881135,  0.20400353, -0.22411636, ...,  0.13221377,
#           0.06093576, -0.03782939],
#         [-0.12605232, -0.21781929, -0.24058545, ..., -0.2240249 ,
#           0.07037409,  0.14693539]], dtype=float32)>,
#  <tf.Variable 'mlp_1/dense_1/bias:0' shape=(50,) dtype=float32, numpy=
#  array([ 0.02232766, -0.02292164,  0.00678176,  0.02064247,  0.02341934,
#          0.03503467, -0.02945454, -0.0246027 , -0.02510202,  0.01960882,
#         -0.02351099, -0.03449445, -0.02739692,  0.0225089 ,  0.01918425,
#         -0.00269253, -0.02388661,  0.02060913, -0.02987951,  0.01971237,
#         -0.01370096, -0.02275538,  0.02288285, -0.01657183,  0.03120288,
#          0.02177486,  0.02173235,  0.03640188, -0.0187916 ,  0.02056885,
#          0.02811644,  0.02670865, -0.02305842, -0.0218829 , -0.0265462 ,
#          0.02230959,  0.02556929,  0.02145798, -0.02179684,  0.02659696,
#         -0.02109742, -0.02080285,  0.02390721, -0.02239119,  0.02272346,
#         -0.02141809,  0.03102357,  0.02291185, -0.02209286, -0.01950012],
#        dtype=float32)>,
#  <tf.Variable 'mlp_1/dense_2/kernel:0' shape=(50, 3) dtype=float32, numpy=
#  array([[ 0.14298597, -0.2058208 ,  0.0851113 ],
#         [-0.1582897 , -0.04685941, -0.21570335],
#         [-0.24570966,  0.19627395,  0.2665685 ],
#         [ 0.2130427 , -0.32539997,  0.33288497],
#         [-0.00060958, -0.19750504,  0.06882387],
#         [ 0.04801705, -0.05125287,  0.15545565],
#         [-0.24864152,  0.0793359 , -0.01901767],
#         [-0.16725779,  0.07926321, -0.2900517 ],
#         [ 0.13324979,  0.03138307, -0.2666854 ],
#         [-0.00285724,  0.21343598,  0.09429975],
#         [ 0.19043615, -0.00608903, -0.29631844],
#         [ 0.12765425, -0.18384157, -0.03749871],
#         [ 0.28607306,  0.28327802, -0.0551925 ],
#         [ 0.01130673,  0.03674412,  0.11917852],
#         [-0.31373996, -0.02156827,  0.0939507 ],
#         [-0.21390086, -0.2438465 , -0.00676492],
#         [-0.21286725,  0.15837279, -0.05293513],
#         [ 0.28066704, -0.29170346,  0.05401963],
#         [-0.15228064, -0.06720531, -0.22003047],
#         [-0.04823887,  0.33145657,  0.21714826],
#         [-0.3245044 ,  0.26389733, -0.3228954 ],
#         [-0.31926057,  0.07199112, -0.21456997],
#         [ 0.09901026,  0.31227902,  0.22486784],
#         [ 0.20721975,  0.22653916, -0.03598951],
#         [-0.2570362 , -0.06508055,  0.24898759],
#         [-0.03423783, -0.17476974,  0.13645521],
#         [ 0.3277996 ,  0.03690037,  0.27730426],
#         [-0.26628417,  0.27745155,  0.16618446],
#         [ 0.2144554 ,  0.22807053, -0.17844947],
#         [-0.06471235, -0.30156463,  0.2232959 ],
#         [-0.13341263, -0.245905  ,  0.31882566],
#         [-0.2569824 ,  0.19648352,  0.19535848],
#         [-0.2552024 , -0.09004675, -0.31074095],
#         [-0.16835198, -0.30777743, -0.09225542],
#         [ 0.2864786 ,  0.10782379, -0.20606673],
#         [ 0.08305365,  0.00174004,  0.26672623],
#         [ 0.16973767, -0.22438109,  0.09150845],
#         [-0.17573237, -0.17295688,  0.28926158],
#         [ 0.14063507,  0.15767208, -0.30599365],
#         [ 0.283545  , -0.29745242,  0.04228855],
#         [-0.302868  ,  0.11818656, -0.22059734],
#         [-0.03945971, -0.09248893, -0.11582412],
#         [ 0.22133443, -0.23194286,  0.1423061 ],
#         [ 0.2479538 ,  0.05866992, -0.23272426],
#         [ 0.02081951,  0.08273029,  0.15985943],
#         [-0.08860353, -0.13441513, -0.23447356],
#         [ 0.11103863, -0.28886682,  0.01963003],
#         [ 0.05237433,  0.16324827,  0.18270573],
#         [ 0.23519543,  0.00561428, -0.3046445 ],
#         [-0.10937634, -0.09627175, -0.304188  ]], dtype=float32)>,
#  <tf.Variable 'mlp_1/dense_2/bias:0' shape=(3,) dtype=float32, numpy=array([0.        , 0.        , 0.01667065], dtype=float32)>,
#  <tf.Variable 'shift_2/w:0' shape=(3,) dtype=float32, numpy=array([ 0.0079827 , -0.00200736, -0.00908471], dtype=float32)>,
#  <tf.Variable 'shift_2/b:0' shape=(3,) dtype=float32, numpy=array([ 0.00554718,  0.10049099, -0.0158996 ], dtype=float32)>,
#  <tf.Variable 'mlp_2/dense/kernel:0' shape=(3, 50) dtype=float32, numpy=
#  array([[-0.07888006, -0.1811475 ,  0.24229656,  0.1656123 ,  0.14533223,
#          -0.15663524, -0.12930799,  0.10649824, -0.20941424,  0.1752375 ,
#          -0.04910347, -0.03948393,  0.2090739 ,  0.21031877,  0.0276206 ,
#           0.3420434 ,  0.02242154, -0.07735927,  0.04946166,  0.2896858 ,
#           0.27765083,  0.25975606,  0.35229835, -0.16108628, -0.04066396,
#           0.04918951, -0.3193258 , -0.1813367 ,  0.28975958, -0.21764001,
#           0.18585062,  0.08880158, -0.24482045,  0.19866878,  0.11112123,
#           0.10843062, -0.30947605,  0.29155424, -0.05284366,  0.09959175,
#          -0.18620455, -0.08089881, -0.05783849,  0.00427813, -0.03398752,
#          -0.27633682, -0.24670225,  0.07016005, -0.07558137, -0.27803722],
#         [-0.29391533, -0.02920353, -0.12613091,  0.14707074, -0.3340293 ,
#           0.24246153,  0.16939208,  0.12026864,  0.24460915,  0.03240561,
#          -0.03412697,  0.10352933,  0.04152495,  0.09624022,  0.11465773,
#          -0.02054957, -0.26478022, -0.2975888 ,  0.2942777 ,  0.12977943,
#          -0.14499009, -0.3322113 , -0.19631186,  0.14466289,  0.26010796,
#          -0.02764985,  0.07557827, -0.21307236, -0.31290904, -0.1701342 ,
#          -0.23534039,  0.30069843, -0.08934459, -0.26102757,  0.26452217,
#           0.13189185, -0.23475406,  0.00352162, -0.059035  ,  0.29616114,
#          -0.03426647, -0.26434264,  0.27407208,  0.21136561, -0.11959963,
#          -0.2784178 ,  0.15350175, -0.08546168, -0.27499637, -0.27491745],
#         [ 0.32160926,  0.3393917 ,  0.04676268, -0.14599954,  0.2218533 ,
#           0.29147473, -0.17638442,  0.33016565,  0.20276377, -0.09428413,
#           0.0391617 , -0.06934975,  0.38412228,  0.12646031,  0.15323782,
#          -0.08054285, -0.13536145, -0.2526832 , -0.25879067,  0.10359643,
#          -0.09038924,  0.12923692,  0.09744185, -0.18028364, -0.1778856 ,
#           0.4038294 ,  0.27522132, -0.2966595 ,  0.12867121,  0.16814485,
#          -0.14645322,  0.18126969,  0.35803053, -0.28411427, -0.39027268,
#           0.12420152, -0.09497739,  0.16117208,  0.22725174, -0.11072306,
#           0.26901373, -0.11170611, -0.15864122, -0.12282021, -0.15963641,
#           0.282501  , -0.19348834, -0.06616335,  0.1436721 ,  0.22858864]],
#        dtype=float32)>,
#  <tf.Variable 'mlp_2/dense/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-0.18179056, -0.17415462,  0.18688239, -0.01061639, -0.03378531,
#         -0.09032099, -0.03123084, -0.19439998, -0.19813849,  0.05175898,
#          0.11662026,  0.03109664, -0.15464197, -0.10727211, -0.05885987,
#         -0.08401196, -0.05591453, -0.07609529,  0.08628334, -0.02417593,
#         -0.01395783, -0.01191635,  0.06201604,  0.21652812, -0.02139776,
#         -0.25499585,  0.06950299, -0.07544218, -0.04336048,  0.06491493,
#         -0.06615205,  0.05820841, -0.24483891, -0.06317659,  0.18231842,
#          0.03069248,  0.0829768 ,  0.00761489,  0.05479487, -0.02941828,
#         -0.0347191 , -0.06156387,  0.24395356,  0.11312962, -0.03850245,
#         -0.03519054,  0.09348687,  0.03520621, -0.09058694,  0.0978089 ],
#        dtype=float32)>,
#  <tf.Variable 'mlp_2/dense_1/kernel:0' shape=(50, 50) dtype=float32, numpy=
#  array([[ 5.2474361e-02, -1.5490553e-01, -2.2780047e-01, ...,
#           1.0962635e-01,  9.4011366e-02,  1.2257429e-01],
#         [ 2.1088511e-01,  2.3054933e-02,  1.9606970e-01, ...,
#          -3.5195138e-02, -1.7958894e-02, -2.1269494e-01],
#         [-1.0249804e-01, -1.6034362e-01,  2.2683953e-01, ...,
#           4.2053562e-02, -1.4275269e-04, -6.4547688e-02],
#         ...,
#         [ 2.3261106e-01, -2.5035491e-02,  1.8470234e-01, ...,
#           1.2159849e-01, -7.6142915e-02,  1.0797844e-01],
#         [ 1.2540678e-02,  2.6535991e-01, -9.8221041e-02, ...,
#           2.3892976e-01, -1.2874578e-01,  4.2039778e-02],
#         [ 4.0526092e-02, -4.9295329e-02, -2.0825209e-01, ...,
#          -2.4146082e-02, -1.8295619e-01,  1.3915080e-01]], dtype=float32)>,
#  <tf.Variable 'mlp_2/dense_1/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-0.00439132, -0.01467085, -0.00349601,  0.1632299 , -0.02284364,
#         -0.05680974,  0.03791677, -0.01998914,  0.03034326,  0.00868048,
#          0.00237201,  0.00532788,  0.00824836,  0.00804261, -0.07195772,
#         -0.03300807,  0.01325761,  0.0549882 ,  0.00392509, -0.02991344,
#         -0.03508247, -0.00809458, -0.0168457 ,  0.05975562,  0.00085728,
#          0.01856976,  0.01043422, -0.08824889,  0.01290791, -0.01644667,
#          0.00919202, -0.05589423, -0.00117947,  0.00202178,  0.03097429,
#          0.06568325,  0.06041928,  0.02243773,  0.08256053, -0.20971401,
#          0.00620943, -0.00740616, -0.00947023, -0.02289484,  0.00153342,
#         -0.01070381,  0.00184571,  0.02242903, -0.03993095,  0.01860214],
#        dtype=float32)>,
#  <tf.Variable 'mlp_2/dense_2/kernel:0' shape=(50, 3) dtype=float32, numpy=
#  array([[ 0.32726356, -0.01316047, -0.16252358],
#         [-0.24271284,  0.14434865,  0.0151687 ],
#         [ 0.02333292, -0.15428936,  0.08594498],
#         [-0.11223912,  0.24307077,  0.17538455],
#         [ 0.28753898, -0.24379322, -0.03081626],
#         [-0.12921965, -0.20844601,  0.00394687],
#         [-0.22822046,  0.01050222,  0.18131778],
#         [ 0.3155038 , -0.08691835,  0.04796365],
#         [ 0.1901097 ,  0.0824399 ,  0.20790568],
#         [ 0.01806542,  0.19346093, -0.08324873],
#         [ 0.2967653 , -0.21825938,  0.23294577],
#         [ 0.09008726,  0.01979377, -0.2381118 ],
#         [-0.08022937,  0.17900744,  0.06443262],
#         [ 0.19578883, -0.14744157,  0.3227751 ],
#         [-0.32376686, -0.20297298, -0.2514025 ],
#         [ 0.27046242, -0.2772165 , -0.299209  ],
#         [ 0.01273951,  0.20575005,  0.25128195],
#         [-0.17369136,  0.22928534,  0.28220728],
#         [ 0.29958495, -0.11617642,  0.09367552],
#         [-0.08753501, -0.22006577, -0.2998768 ],
#         [ 0.13561463, -0.3204731 , -0.152765  ],
#         [-0.29283735, -0.29837167,  0.33561257],
#         [ 0.00634646, -0.00734525,  0.03498074],
#         [-0.01790917,  0.14209113, -0.19851765],
#         [ 0.11184266,  0.11582685, -0.12292776],
#         [-0.16638172,  0.32762733, -0.23212945],
#         [ 0.0052141 ,  0.09514689,  0.30667946],
#         [-0.01531839, -0.17877685, -0.08899146],
#         [ 0.19581959,  0.20615077,  0.2558333 ],
#         [-0.17556712, -0.25629658, -0.23277184],
#         [-0.19901237,  0.21189852, -0.06663954],
#         [-0.15693904, -0.17162919,  0.01135805],
#         [ 0.2469131 , -0.267587  ,  0.07376218],
#         [ 0.31078652,  0.00214391, -0.12217946],
#         [-0.06907603,  0.04466206,  0.21210924],
#         [-0.12806651,  0.2802224 ,  0.04645199],
#         [ 0.31897315,  0.09505247,  0.13356295],
#         [-0.0574064 ,  0.33016962,  0.00641039],
#         [ 0.1399355 ,  0.33820233, -0.32614952],
#         [ 0.24179503, -0.02812251,  0.15019199],
#         [-0.1490029 ,  0.10711641, -0.08481869],
#         [-0.05616507, -0.06886897,  0.10003716],
#         [-0.3025234 , -0.31632152,  0.2000967 ],
#         [ 0.25119302, -0.13150837,  0.20858154],
#         [-0.19300981, -0.11102351, -0.2331987 ],
#         [ 0.14434627, -0.29211363, -0.11551021],
#         [-0.00687292, -0.00861812,  0.02862963],
#         [-0.30856904,  0.16178918, -0.14232546],
#         [ 0.20547697, -0.11608487, -0.1770616 ],
#         [-0.2068606 ,  0.22809309, -0.12947868]], dtype=float32)>,
#  <tf.Variable 'mlp_2/dense_2/bias:0' shape=(3,) dtype=float32, numpy=array([0.        , 0.00751243, 0.        ], dtype=float32)>,
#  <tf.Variable 'shift_3/w:0' shape=(3,) dtype=float32, numpy=array([0.00555122, 0.01731751, 0.00588148], dtype=float32)>,
#  <tf.Variable 'shift_3/b:0' shape=(3,) dtype=float32, numpy=array([ 0.00014181, -0.00804001, -0.01870251], dtype=float32)>,
#  <tf.Variable 'mlp_3/dense/kernel:0' shape=(3, 50) dtype=float32, numpy=
#  array([[-0.03477406, -0.03087615, -0.03747885, -0.11053089,  0.07578246,
#          -0.1079253 , -0.12615749, -0.01775534, -0.2743579 , -0.3310887 ,
#          -0.33122003, -0.16465504, -0.04580969, -0.00544731,  0.2554722 ,
#          -0.15074295,  0.36822286, -0.07740963,  0.26649937, -0.03141163,
#          -0.02912701, -0.2518204 ,  0.34385496,  0.13310663, -0.36168557,
#          -0.13846937, -0.32386273,  0.1798485 ,  0.05913227, -0.05088311,
#           0.33622572,  0.13331386, -0.19037901,  0.105698  , -0.2634103 ,
#          -0.04876035, -0.2903844 , -0.32928494, -0.01186088, -0.1335502 ,
#           0.19734928,  0.12256167, -0.32846847, -0.2982031 ,  0.07875688,
#          -0.05313434, -0.39277375,  0.12026367, -0.27039832, -0.44285312],
#         [ 0.30630597,  0.25802618,  0.13132241,  0.1816199 ,  0.2866821 ,
#           0.08937986, -0.01540082,  0.26068768, -0.14703159,  0.10517841,
#          -0.3903524 , -0.3357032 ,  0.09203372, -0.18584862,  0.04529193,
#          -0.1741116 , -0.09708779, -0.0831589 , -0.25521213, -0.13029014,
#          -0.0480127 ,  0.11729097,  0.22919303, -0.01241746,  0.16049734,
#           0.1803134 , -0.22477834, -0.02557582,  0.30418336,  0.20824826,
#          -0.13558449,  0.27021486,  0.18595475, -0.10590336,  0.03751591,
#           0.04299017,  0.09706213, -0.2628236 ,  0.13445456, -0.277933  ,
#          -0.27070394,  0.32722276,  0.16259769, -0.10378165,  0.0104364 ,
#           0.23847882, -0.2729996 ,  0.00619659, -0.3189445 ,  0.25377268],
#         [ 0.19743326, -0.26070648,  0.24045107, -0.30519712, -0.30454004,
#          -0.2382504 , -0.15240201,  0.24678752,  0.06540793,  0.2275556 ,
#          -0.01550129, -0.31410286, -0.19116084, -0.04503196, -0.27252018,
#          -0.3214023 ,  0.2588435 ,  0.19401136, -0.26980573, -0.2606744 ,
#           0.10745981, -0.20014578,  0.11937863,  0.16976383,  0.0057314 ,
#           0.26772586,  0.17926916, -0.32199708,  0.03544721,  0.27621332,
#          -0.01538202,  0.05766895,  0.16306168, -0.2647353 , -0.20444937,
#          -0.03247863,  0.09653246,  0.24463823,  0.3345094 , -0.13282672,
#           0.07244948,  0.00100899,  0.24291506,  0.30221984,  0.10642701,
#           0.11340848,  0.20524386, -0.22972119, -0.09081396,  0.05330366]],
#        dtype=float32)>,
#  <tf.Variable 'mlp_3/dense/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-0.03238861, -0.02960348, -0.00985673, -0.00245853,  0.01408165,
#         -0.00400388,  0.00352957, -0.03509002, -0.01552428,  0.01973031,
#         -0.00201368, -0.01577232,  0.01707497,  0.00791431, -0.0069    ,
#          0.00404279, -0.02580583, -0.00768282,  0.02250122, -0.01179766,
#          0.00238906,  0.02528227,  0.01305429,  0.0071888 ,  0.0438057 ,
#          0.02597292, -0.0097746 , -0.00775433,  0.00722358,  0.01317204,
#         -0.02015599, -0.0051556 ,  0.01840034,  0.01099707, -0.00351412,
#          0.00729348,  0.06980151,  0.0002414 , -0.00031382, -0.00380008,
#         -0.03378321, -0.03366311, -0.01624594, -0.00605727, -0.00930142,
#          0.0166904 , -0.00403713,  0.00391736,  0.01122353,  0.06353334],
#        dtype=float32)>,
#  <tf.Variable 'mlp_3/dense_1/kernel:0' shape=(50, 50) dtype=float32, numpy=
#  array([[-0.01364847,  0.15948296, -0.1547555 , ..., -0.16121541,
#          -0.10018797,  0.16357352],
#         [-0.16381605, -0.01280888, -0.146437  , ...,  0.09599316,
#          -0.09718242, -0.09977496],
#         [-0.18159634,  0.02452378,  0.1753543 , ..., -0.1849188 ,
#           0.04057793,  0.13806805],
#         ...,
#         [ 0.02082437, -0.17156325,  0.03235178, ..., -0.17856215,
#           0.16713153, -0.03071292],
#         [-0.09992208,  0.22296584,  0.0027494 , ...,  0.04337831,
#           0.09741995,  0.11246412],
#         [ 0.14039633,  0.22374816, -0.14295742, ...,  0.02212952,
#           0.02207456, -0.09297896]], dtype=float32)>,
#  <tf.Variable 'mlp_3/dense_1/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-1.6322697e-02,  6.0229506e-03, -5.4830378e-03,  6.9375373e-03,
#          1.0861574e-03,  1.6037812e-02, -2.5071520e-03, -8.9714760e-03,
#         -1.6249251e-02,  4.4460120e-03, -1.3984531e-03, -7.7370233e-03,
#          3.8827993e-03,  6.5822257e-03, -8.6925542e-03,  4.7590290e-03,
#         -4.8310873e-03, -1.1981321e-03, -8.5974541e-03, -4.0346496e-03,
#         -2.9487892e-06, -3.0762258e-03, -5.8640423e-03,  2.9678527e-02,
#          9.9538304e-03,  1.0222194e-02,  4.5853709e-03, -7.7677458e-03,
#          3.4633069e-04,  5.6414846e-03,  7.5404434e-03, -7.2739384e-04,
#         -5.1472834e-03,  1.2334771e-03,  2.8205314e-03, -1.7997889e-02,
#          1.1752104e-02, -1.0549243e-02,  3.3617183e-03, -1.8487317e-03,
#         -2.2311904e-02,  1.0314851e-02,  7.0165293e-03, -3.3728830e-03,
#         -7.0634955e-03,  3.1998188e-03,  6.6434359e-03,  4.9906303e-03,
#         -5.1190024e-03, -8.3086658e-03], dtype=float32)>,
#  <tf.Variable 'mlp_3/dense_2/kernel:0' shape=(50, 3) dtype=float32, numpy=
#  array([[ 0.20215526,  0.15003538,  0.04893248],
#         [ 0.15953591,  0.04058829,  0.15868038],
#         [-0.03038859,  0.31004396, -0.2861175 ],
#         [ 0.25944164,  0.00668907, -0.09432123],
#         [ 0.00637686, -0.20628816,  0.0203515 ],
#         [ 0.18716708,  0.1632677 ,  0.04868146],
#         [ 0.25255647, -0.03709501, -0.16387266],
#         [-0.11031707,  0.190088  , -0.21797846],
#         [ 0.25365546, -0.02928534,  0.21085317],
#         [-0.0698868 , -0.07675853,  0.14246689],
#         [ 0.22281739,  0.02026471, -0.1832928 ],
#         [-0.21215627,  0.05467775, -0.18386307],
#         [-0.15839694,  0.22181681,  0.30109626],
#         [ 0.26993278,  0.21496114,  0.21703602],
#         [ 0.1773456 ,  0.24567237, -0.07314306],
#         [ 0.20234248, -0.25951248,  0.20203109],
#         [ 0.29476765, -0.12087053, -0.21115874],
#         [-0.2439191 , -0.20124173,  0.27181274],
#         [-0.07747552, -0.18454164, -0.0363761 ],
#         [-0.30033284,  0.22925815, -0.11359514],
#         [-0.2026357 , -0.04060811, -0.02405267],
#         [-0.28565508,  0.00571024, -0.08561017],
#         [ 0.07120016, -0.02397853, -0.2136938 ],
#         [-0.04651642, -0.21884245,  0.00898481],
#         [ 0.31824812,  0.03579578, -0.2094862 ],
#         [-0.29318687,  0.10642844, -0.12627724],
#         [ 0.23455128,  0.04651642, -0.07522482],
#         [-0.24947178, -0.16612494, -0.2604384 ],
#         [ 0.31253424,  0.26824132,  0.1879599 ],
#         [-0.2793602 , -0.24519001,  0.33238274],
#         [-0.2101913 ,  0.12162468,  0.19094355],
#         [ 0.2413353 , -0.2955182 , -0.32856458],
#         [-0.1900948 , -0.27571657,  0.25423437],
#         [ 0.2981979 ,  0.2034308 , -0.15154761],
#         [ 0.24458405, -0.3198589 ,  0.00596848],
#         [-0.30720457,  0.13716304,  0.03953771],
#         [-0.0814552 ,  0.0235399 ,  0.00838249],
#         [-0.01082975, -0.25110626,  0.16883127],
#         [ 0.29069296, -0.01482001,  0.01179396],
#         [ 0.24744728,  0.17531642,  0.12302905],
#         [ 0.19632396,  0.20276198,  0.10504488],
#         [ 0.2568303 ,  0.302022  , -0.28402203],
#         [ 0.29670647, -0.3269657 ,  0.08142252],
#         [ 0.01748833, -0.16748689,  0.01782532],
#         [ 0.3129755 , -0.0187861 , -0.27994746],
#         [ 0.20391366,  0.18363813,  0.15530092],
#         [ 0.15184039,  0.00447655,  0.07432835],
#         [-0.31090695,  0.22220412, -0.24182193],
#         [-0.32870963,  0.08871904, -0.14182067],
#         [ 0.2708803 ,  0.2606806 , -0.02330284]], dtype=float32)>,
#  <tf.Variable 'mlp_3/dense_2/bias:0' shape=(3,) dtype=float32, numpy=array([0.        , 0.        , 0.00954434], dtype=float32)>,
#  <tf.Variable 'shift_4/w:0' shape=(3,) dtype=float32, numpy=array([ 0.00375391, -0.00352802,  0.00451767], dtype=float32)>,
#  <tf.Variable 'shift_4/b:0' shape=(3,) dtype=float32, numpy=array([-0.06996462, -0.00209333,  0.02469764], dtype=float32)>,
#  <tf.Variable 'mlp_4/dense/kernel:0' shape=(3, 50) dtype=float32, numpy=
#  array([[ 0.26972732, -0.07249257,  0.06537488, -0.14027786, -0.07445776,
#           0.18692014,  0.03688547, -0.21382457, -0.04668278, -0.27677372,
#           0.03689757,  0.04906073,  0.31945667, -0.12829345,  0.18931237,
#           0.04600003,  0.15003875,  0.11164084,  0.01295081, -0.26876128,
#          -0.16369759,  0.06625071, -0.12596774,  0.0604938 ,  0.00242221,
#           0.05202419,  0.29611567, -0.17334153,  0.03718042, -0.09995164,
#          -0.18952918,  0.09178662, -0.2980978 ,  0.1813899 , -0.1877853 ,
#          -0.3108235 ,  0.24028996,  0.2650819 ,  0.05866456,  0.05886847,
#          -0.16931117, -0.3033998 ,  0.0788776 ,  0.31061825,  0.23758802,
#           0.06174481,  0.081561  , -0.31922445, -0.21296817,  0.27015588],
#         [-0.02138232, -0.20822437,  0.18032838,  0.01650871, -0.3184137 ,
#          -0.16927384,  0.00412058,  0.08913666, -0.07756797, -0.23478436,
#          -0.07759296, -0.17046551,  0.04144625,  0.10133521, -0.14615582,
#          -0.35283732,  0.03026263,  0.06014957, -0.04457556, -0.33073112,
#          -0.03342601,  0.03218988,  0.35531047,  0.10338192,  0.06791103,
#          -0.03783824, -0.29944667, -0.11192242,  0.14366262,  0.06629437,
#          -0.3705383 , -0.04569397, -0.18663883,  0.32026058,  0.2185758 ,
#           0.16742668, -0.32112074,  0.15719457,  0.3945966 ,  0.02645778,
#          -0.2146355 , -0.05571285, -0.09391133, -0.17264357, -0.02464557,
#           0.23288807,  0.06876462,  0.27945483,  0.23490706, -0.30050394],
#         [ 0.21173257,  0.13889174,  0.24293247, -0.04021003,  0.30496272,
#          -0.478314  ,  0.32089436,  0.14423737,  0.3000161 ,  0.12074299,
#          -0.20358585, -0.37008762, -0.23492508,  0.18075001, -0.11741278,
#          -0.19521092, -0.15283194,  0.20719098,  0.08190705, -0.07634666,
#          -0.03373084,  0.26541135,  0.29150918,  0.22674991, -0.09684341,
#          -0.23597236,  0.04233531, -0.30230653, -0.33009115,  0.26574576,
#          -0.16943654,  0.23523234, -0.281858  , -0.12844138,  0.12101224,
#          -0.2905053 ,  0.26735944,  0.27238518,  0.40825903, -0.21884638,
#           0.09091027,  0.05393085, -0.32247844, -0.3133366 ,  0.18331648,
#           0.06377614, -0.11110073, -0.11136857, -0.24871784, -0.1998587 ]],
#        dtype=float32)>,
#  <tf.Variable 'mlp_4/dense/bias:0' shape=(50,) dtype=float32, numpy=
#  array([ 0.01081432, -0.18103921,  0.08289775, -0.03149867, -0.15005173,
#          0.11975513,  0.0899806 , -0.1494326 , -0.08945715, -0.19379154,
#          0.02187685,  0.24682637, -0.08912316, -0.05265103, -0.09065263,
#          0.21230829, -0.31125286, -0.14613234,  0.06442801,  0.11624608,
#         -0.05435611,  0.00122345, -0.13140881, -0.10472465,  0.09896845,
#          0.21489961, -0.12235525,  0.10216405,  0.2080282 , -0.34205905,
#          0.27257764,  0.00506246, -0.0170357 , -0.22589567,  0.13892823,
#          0.04372958,  0.25179893, -0.0590816 , -0.13115549,  0.01524964,
#         -0.15922523,  0.01208355,  0.05440725, -0.02011465,  0.1556884 ,
#          0.13790746,  0.03617399, -0.24548301, -0.19898233,  0.10480921],
#        dtype=float32)>,
#  <tf.Variable 'mlp_4/dense_1/kernel:0' shape=(50, 50) dtype=float32, numpy=
#  array([[-0.14277604, -0.22738062,  0.01095836, ...,  0.2116397 ,
#          -0.2408887 , -0.00225236],
#         [-0.07965199, -0.04149543, -0.15168479, ..., -0.05001859,
#          -0.03163775, -0.14776744],
#         [ 0.23876566,  0.1195485 , -0.06350387, ..., -0.02330996,
#           0.16458373,  0.09448693],
#         ...,
#         [ 0.04717023,  0.07728661, -0.06640138, ..., -0.02109116,
#           0.22513779, -0.05798766],
#         [-0.0781434 , -0.13832803, -0.06321676, ...,  0.18722078,
#           0.05514397,  0.19892366],
#         [-0.18585972,  0.0767785 ,  0.16836432, ...,  0.03884581,
#          -0.08712893,  0.10319415]], dtype=float32)>,
#  <tf.Variable 'mlp_4/dense_1/bias:0' shape=(50,) dtype=float32, numpy=
#  array([-0.1051859 , -0.04795019, -0.01122122,  0.10816274, -0.09504813,
#         -0.0070185 , -0.0192862 ,  0.03672012, -0.05305576, -0.02535175,
#         -0.01801092,  0.02033182, -0.00743072,  0.08229471,  0.01160005,
#          0.07621831,  0.04082773,  0.04656814,  0.02499859, -0.03375189,
#          0.0386752 , -0.02346431,  0.02277786, -0.07786998, -0.09949799,
#          0.22864223,  0.12542991,  0.2874678 , -0.01973147,  0.01607053,
#          0.0213694 ,  0.05257477, -0.10167547, -0.01888313, -0.02502969,
#          0.01622907, -0.09316806, -0.14237505,  0.02835777,  0.02795558,
#          0.05939336,  0.00220456, -0.00986031, -0.04853481, -0.02114801,
#         -0.03533612,  0.06431533, -0.03952651,  0.02685145,  0.01861046],
#        dtype=float32)>,
#  <tf.Variable 'mlp_4/dense_2/kernel:0' shape=(50, 3) dtype=float32, numpy=
#  array([[ 0.2475667 , -0.27229357, -0.13667145],
#         [-0.11715303, -0.05676752, -0.2520059 ],
#         [ 0.06544001,  0.02112144, -0.30779508],
#         [-0.33060527, -0.29559278, -0.06616744],
#         [ 0.11446431, -0.21445847, -0.10894042],
#         [ 0.22790675, -0.07344323, -0.13883287],
#         [-0.33492845, -0.208585  ,  0.0240646 ],
#         [ 0.00049024,  0.28648522,  0.2306957 ],
#         [ 0.26487416, -0.02548817, -0.22176763],
#         [-0.00292207, -0.09846534,  0.29030547],
#         [-0.05638837,  0.1513522 , -0.13153543],
#         [ 0.0988445 , -0.23198506, -0.11835237],
#         [-0.31737325,  0.11916274, -0.23679034],
#         [ 0.02273938, -0.12391108,  0.13110247],
#         [ 0.12924403, -0.21206112, -0.2933923 ],
#         [-0.08721092, -0.30171424,  0.18067393],
#         [-0.03510478,  0.06756014, -0.26311904],
#         [ 0.12553293, -0.13680172,  0.1539906 ],
#         [-0.20294663,  0.03042501,  0.09284976],
#         [ 0.0321622 ,  0.28189227, -0.295463  ],
#         [ 0.05678125, -0.33215073,  0.15222234],
#         [ 0.26740524, -0.25280952,  0.09529507],
#         [ 0.13058162, -0.32832292,  0.04751948],
#         [ 0.3310268 ,  0.0591608 ,  0.01929453],
#         [ 0.28458616, -0.29155192,  0.0983654 ],
#         [-0.11665052,  0.01152852,  0.13296556],
#         [-0.10159855, -0.05730468,  0.1937851 ],
#         [-0.13769482, -0.14125614, -0.33590016],
#         [-0.35776857,  0.16043532, -0.11467513],
#         [-0.04880376,  0.3158696 , -0.01388359],
#         [-0.3067663 ,  0.05307096, -0.0413146 ],
#         [ 0.066273  , -0.01107657,  0.24859515],
#         [ 0.14908549, -0.28647605, -0.06370014],
#         [-0.2469571 , -0.17334914, -0.2554846 ],
#         [-0.2701149 ,  0.1257112 , -0.04954565],
#         [-0.33800322, -0.04156673,  0.1512309 ],
#         [ 0.09926947,  0.13006091, -0.08611849],
#         [ 0.10106663,  0.3204219 ,  0.21386251],
#         [ 0.24773936, -0.26505843, -0.32332894],
#         [ 0.228402  , -0.25059414, -0.21977636],
#         [-0.1293451 ,  0.17005286,  0.27275625],
#         [-0.23365404,  0.24117544, -0.21865626],
#         [-0.1435235 , -0.26686168, -0.2759744 ],
#         [-0.19773817, -0.25965536, -0.24343681],
#         [ 0.18450437, -0.13611376,  0.01707768],
#         [-0.1118853 , -0.2173864 ,  0.138269  ],
#         [-0.04992149,  0.09452602, -0.25496167],
#         [ 0.06927235, -0.32577306, -0.21615839],
#         [ 0.1583406 ,  0.01697877, -0.08765525],
#         [ 0.24832167,  0.32569757, -0.14117591]], dtype=float32)>,
#  <tf.Variable 'mlp_4/dense_2/bias:0' shape=(3,) dtype=float32, numpy=array([0.02276552, 0.        , 0.        ], dtype=float32)>]

# %%
plt.figure(figsize = (10,5))
#plt.plot(history.history["val_loss"])
plt.plot(history.history["loss"])
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.title(r'NN', fontsize = 30)
plt.xlabel(r'epochs', fontsize=20)
plt.ylabel(r'loss', fontsize=20)
plt.yscale("log")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(axis='both', alpha=.3)
#plt.savefig("loss_Henon_E01667")

# %%
x0 = x_train[10]

f_iterations = [model(x0)]

# %%
for _ in range(10):
    f_iterations.append(model(f_iterations[-1]))

#b_iterations = [f_iterations[-1]*np.array([[-1., -1., -1.]])]

#for _ in range(100):
    #b_iterations.append(model(b_iterations[-1]))

# %%
plt.plot([i[0].numpy() for i in f_iterations])
# Out:
# [<matplotlib.lines.Line2D at 0x2699744cf88>,
#  <matplotlib.lines.Line2D at 0x26997457f48>,
#  <matplotlib.lines.Line2D at 0x2699745f148>,
#  <matplotlib.lines.Line2D at 0x2699745f308>,
#  <matplotlib.lines.Line2D at 0x2699745f508>,
#  <matplotlib.lines.Line2D at 0x2699745f708>,
#  <matplotlib.lines.Line2D at 0x2699745f8c8>,
#  <matplotlib.lines.Line2D at 0x2699745fa88>]

# %%
plt.plot(x_train[10:15])
# Out:
# [<matplotlib.lines.Line2D at 0x2699750ad08>,
#  <matplotlib.lines.Line2D at 0x26997516cc8>,
#  <matplotlib.lines.Line2D at 0x26997516e88>,
#  <matplotlib.lines.Line2D at 0x2699751d088>,
#  <matplotlib.lines.Line2D at 0x2699751d288>,
#  <matplotlib.lines.Line2D at 0x2699751d488>,
#  <matplotlib.lines.Line2D at 0x2699751d648>,
#  <matplotlib.lines.Line2D at 0x2699751d808>]

# %%
y_train
# Out:
# array([[ 8.0828404e-04,  1.3378504e-04,  3.1356519e-04, ...,
#          4.8662148e-02, -3.1356520e-03,  9.2169847e-03],
#        [ 2.9731386e-03,  9.6673059e-04,  5.3282344e-04, ...,
#          9.0332694e-02, -5.3282343e-03,  7.3423334e-03],
#        [ 5.9478343e-03,  2.8346539e-03,  6.4043817e-04, ...,
#          1.2165346e-01, -6.4043817e-03,  5.1935432e-03],
#        ...,
#        [ 1.5491356e-02,  1.8223394e+00, -6.0058612e-04, ...,
#          1.6766056e+00,  6.0058613e-03,  4.2853114e-04],
#        [ 1.2363537e-02,  1.8268144e+00, -6.4733712e-04, ...,
#          1.6818560e+00,  6.4733708e-03,  1.7224055e-03],
#        [ 9.0625966e-03,  1.8305620e+00, -6.6699821e-04, ...,
#          1.6943799e+00,  6.6699819e-03,  3.3452539e-03]], dtype=float32)

# %%
model(x_train)-y_train
# Out:
# <tf.Tensor: shape=(400, 8), dtype=float32, numpy=
# array([[-0.00055984, -0.00022432, -0.00019096, ..., -0.04120364,
#          0.0033559 ,  0.00128436],
#        [-0.00089648, -0.00041968, -0.00012235, ..., -0.01447354,
#          0.00157259,  0.00220604],
#        [-0.0009729 , -0.00105084, -0.00010581, ...,  0.00107168,
#          0.0002618 ,  0.00233865],
#        ...,
#        [ 0.00012898, -0.00147879,  0.00055482, ...,  0.00091696,
#         -0.00091054, -0.00093902],
#        [ 0.00024387, -0.00187588,  0.00059383, ...,  0.000175  ,
#         -0.00065751, -0.00132715],
#        [ 0.00035107, -0.00211751,  0.00060735, ..., -0.00092518,
#         -0.00022589, -0.00180457]], dtype=float32)>
